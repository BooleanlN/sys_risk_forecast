# %%
import warnings

warnings.simplefilter('ignore')

import os
import re
import gc
import json

import numpy as np
import pandas as pd

pd.set_option('max_columns', None)
pd.set_option('max_rows', 200)
pd.set_option('float_format', lambda x: '%.3f' % x)
# from tqdm.autonotebook import tqdm

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.metrics import roc_auc_score

import lightgbm as lgb

# %%
train = pd.read_csv('dataset/train_dataset.csv', sep='\t')
train.shape
# Out:
# (15016, 19)

# %%
test = pd.read_csv('dataset/test_dataset.csv', sep='\t')
test.shape
# Out:
# (10000, 18)

# %%
train.head()
# Out:
#                           session_id         op_date user_name action  \
# 0  access:test_d:20180101111639:bBp1  2018/1/1 11:16    test_d  login
# 1  access:test_d:20180101121524:OBSg  2018/1/1 12:15    test_d  login
# 2  access:test_d:20180101151333:BpQN  2018/1/1 15:13    test_d  login
# 3  access:test_d:20180101124502:hYQm  2018/1/1 12:45    test_d    sso
# 4  access:test_d:20180101202749:FkDK  2018/1/1 20:27    test_d    sso
#
#   auth_type               ip ip_location_type_keyword ip_risk_level  \
# 0       otp  192.168.100.101                       内网            1级
# 1        qr  192.168.100.101                       内网            1级
# 2        qr  192.168.100.101                       内网            1级
# 3       NaN  192.168.100.101                       内网            1级
# 4       NaN  192.168.100.101                       内网            1级
#
#                                             location client_type  \
# 0  {"first_lvl":"成都分公司","sec_lvl":"9楼","third_lvl...         web
# 1  {"first_lvl":"成都分公司","sec_lvl":"9楼","third_lvl...         web
# 2  {"first_lvl":"成都分公司","sec_lvl":"9楼","third_lvl...         web
# 3  {"first_lvl":"成都分公司","sec_lvl":"9楼","third_lvl...         web
# 4  {"first_lvl":"成都分公司","sec_lvl":"9楼","third_lvl...         web
#
#   browser_source    device_model  os_type  os_version browser_type  \
# 0        desktop  think_pad_e460  windows  windows 10       chrome
# 1        desktop  think_pad_e460  windows  windows 10         edge
# 2        desktop  think_pad_e460  windows  windows 10       chrome
# 3        desktop  think_pad_e460  windows  windows 10         edge
# 4        desktop  think_pad_e460  windows  windows 10         edge
#
#   browser_version bus_system_code   op_target  risk_label
# 0       chrome 90        coremail  management           0
# 1         edge 93      order-mgnt       sales           0
# 2       chrome 90      order-mgnt       sales           0
# 3         edge 93              oa  management           0
# 4         edge 93      order-mgnt       sales           0

# %%
types_dict = {
    'risk_label' : train['risk_label'].unique(),
    'ip_risk_level': train['ip_risk_level'].unique(),
    'ip_location_type_keyword': train['ip_location_type_keyword'].unique(),
    'action': train['action'].unique(),
    'browser_source': train['browser_source'].unique(),
    'client_type': train['client_type'].unique(),
}
types_dict
# Out:
# {'risk_label': array([0, 1]),
#  'ip_risk_level': array(['1级', '2级', '3级'], dtype=object),
#  'ip_location_type_keyword': array(['内网', '家庭宽带', '代理IP'], dtype=object),
#  'action': array(['login', 'sso'], dtype=object),
#  'browser_source': array(['desktop'], dtype=object),
#  'client_type': array(['web'], dtype=object)}

# %%
data = pd.concat([train, test])
data.shape
# Out:
# (25016, 19)

# %%
data['location_first_lvl'] = data['location'].astype(str).map(lambda x: json.loads(x)['first_lvl'])
data['location_sec_lvl'] = data['location'].astype(str).map(lambda x: json.loads(x)['sec_lvl'])
data['location_third_lvl'] = data['location'].astype(str).map(lambda x: json.loads(x)['third_lvl'])

# %%
for col in data.columns:
    print(col + ':' +str(data[col].isna().mean()))
# Out:
# session_id:0.0
# op_date:0.0
# user_name:0.0
# action:0.0
# auth_type:0.5036776463063639
# ip:0.0
# ip_location_type_keyword:0.0
# ip_risk_level:0.0
# location:0.0
# client_type:0.0
# browser_source:0.0
# device_model:0.0
# os_type:0.0
# os_version:0.0
# browser_type:0.0
# browser_version:0.0
# bus_system_code:0.0
# op_target:0.0
# risk_label:0.3997441637352095
# location_first_lvl:0.0
# location_sec_lvl:0.0
# location_third_lvl:0.0

# %%
data['auth_type'].fillna('__NaN__', inplace=True)
data.drop(['client_type', 'browser_source'], axis=1, inplace=True)

# %%
for col in ['user_name', 'action', 'auth_type', 'ip',
                 'ip_location_type_keyword', 'ip_risk_level', 'location', 'device_model',
                 'os_type', 'os_version', 'browser_type', 'browser_version',
                 'bus_system_code', 'op_target', 'location_first_lvl', 'location_sec_lvl',
                 'location_third_lvl']:
    lbl = LabelEncoder()
    data[col] = lbl.fit_transform(data[col])

# %%
data['op_date'] = pd.to_datetime(data['op_date'])
data['op_ts'] = data["op_date"].values.astype(np.int64) // 10 ** 9 # 操作时间戳信息
data = data.sort_values(by=['user_name', 'op_ts']).reset_index(drop=True)
data['last_ts'] = data.groupby(['user_name'])['op_ts'].shift(1) # 最近一次操作时间戳信息
data['ts_diff1'] = data['op_ts'] - data['last_ts'] # 操作时间戳间隔

# %%
# 登录ip、登录地、登录设备、登录OS版本、登录浏览器版本类型不一致的数量
for f in ['ip', 'location', 'device_model', 'os_version', 'browser_version']:
    data[f'user_{f}_nunique'] = data.groupby(['user_name'])[f].transform('nunique')

# %%
data.head()
# Out:
#                           session_id             op_date  user_name  action  \
# 0  access:test_a:20180107090803:WZc0 2018-01-07 09:08:00          0       0
# 1  access:test_a:20180107092734:9863 2018-01-07 09:27:00          0       0
# 2  access:test_a:20180107093226:6qbJ 2018-01-07 09:32:00          0       0
# 3  access:test_a:20180107093834:QJrw 2018-01-07 09:38:00          0       1
# 4  access:test_a:20180107094058:vfu7 2018-01-07 09:40:00          0       0
#
#    auth_type  ip  ip_location_type_keyword  ip_risk_level  location  \
# 0          1   2                         1              0         3
# 1          2   2                         1              0         3
# 2          3   2                         1              0         3
# 3          0   2                         1              0         3
# 4          1   2                         1              0         3
#
#    device_model  os_type  os_version  browser_type  browser_version  \
# 0             1        1           1             1                3
# 1             1        1           1             0                1
# 2             1        1           1             1                3
# 3             1        1           1             0                1
# 4             1        1           1             1                3
#
#    bus_system_code  op_target  risk_label  location_first_lvl  \
# 0                5          0       0.000                   1
# 1                5          0       1.000                   1
# 2                4          3       0.000                   1
# 3                5          0       0.000                   1
# 4                3          2       0.000                   1
#
#    location_sec_lvl  location_third_lvl       op_ts        last_ts  ts_diff1  \
# 0                 1                   3  1515316080            NaN       NaN
# 1                 1                   3  1515317220 1515316080.000  1140.000
# 2                 1                   3  1515317520 1515317220.000   300.000
# 3                 1                   3  1515317880 1515317520.000   360.000
# 4                 1                   3  1515318000 1515317880.000   120.000
#
#    user_ip_nunique  user_location_nunique  user_device_model_nunique  \
# 0                5                      5                          4
# 1                5                      5                          4
# 2                5                      5                          4
# 3                5                      5                          4
# 4                5                      5                          4
#
#    user_os_version_nunique  user_browser_version_nunique
# 0                        4                             8
# 1                        4                             8
# 2                        4                             8
# 3                        4                             8
# 4                        4                             8

# %%
# 对用户名、ip、登录地、登录设备、登录系统、登录浏览器版本分组后求数学特征
for method in ['mean', 'max', 'min', 'std', 'sum', 'median','prod']:
    for col in ['user_name', 'ip', 'location', 'device_model', 'os_version', 'browser_version']:
        data[f'ts_diff1_{method}_' + str(col)] = data.groupby(col)['ts_diff1'].transform(method)

# %%
data.head()
# Out:
#                           session_id             op_date  user_name  action  \
# 0  access:test_a:20180107090803:WZc0 2018-01-07 09:08:00          0       0
# 1  access:test_a:20180107092734:9863 2018-01-07 09:27:00          0       0
# 2  access:test_a:20180107093226:6qbJ 2018-01-07 09:32:00          0       0
# 3  access:test_a:20180107093834:QJrw 2018-01-07 09:38:00          0       1
# 4  access:test_a:20180107094058:vfu7 2018-01-07 09:40:00          0       0
#
#    auth_type  ip  ip_location_type_keyword  ip_risk_level  location  \
# 0          1   2                         1              0         3
# 1          2   2                         1              0         3
# 2          3   2                         1              0         3
# 3          0   2                         1              0         3
# 4          1   2                         1              0         3
#
#    device_model  os_type  os_version  browser_type  browser_version  \
# 0             1        1           1             1                3
# 1             1        1           1             0                1
# 2             1        1           1             1                3
# 3             1        1           1             0                1
# 4             1        1           1             1                3
#
#    bus_system_code  op_target  risk_label  location_first_lvl  \
# 0                5          0       0.000                   1
# 1                5          0       1.000                   1
# 2                4          3       0.000                   1
# 3                5          0       0.000                   1
# 4                3          2       0.000                   1
#
#    location_sec_lvl  location_third_lvl       op_ts        last_ts  ts_diff1  \
# 0                 1                   3  1515316080            NaN       NaN
# 1                 1                   3  1515317220 1515316080.000  1140.000
# 2                 1                   3  1515317520 1515317220.000   300.000
# 3                 1                   3  1515317880 1515317520.000   360.000
# 4                 1                   3  1515318000 1515317880.000   120.000
#
#    user_ip_nunique  user_location_nunique  user_device_model_nunique  \
# 0                5                      5                          4
# 1                5                      5                          4
# 2                5                      5                          4
# 3                5                      5                          4
# 4                5                      5                          4
#
#    user_os_version_nunique  user_browser_version_nunique  \
# 0                        4                             8
# 1                        4                             8
# 2                        4                             8
# 3                        4                             8
# 4                        4                             8
#
#    ts_diff1_mean_user_name  ts_diff1_mean_ip  ts_diff1_mean_location  \
# 0                10595.392         26796.424               26796.424
# 1                10595.392         26796.424               26796.424
# 2                10595.392         26796.424               26796.424
# 3                10595.392         26796.424               26796.424
# 4                10595.392         26796.424               26796.424
#
#    ts_diff1_mean_device_model  ts_diff1_mean_os_version  \
# 0                   26421.976                 26421.976
# 1                   26421.976                 26421.976
# 2                   26421.976                 26421.976
# 3                   26421.976                 26421.976
# 4                   26421.976                 26421.976
#
#    ts_diff1_mean_browser_version  ts_diff1_max_user_name  ts_diff1_max_ip  \
# 0                      23323.710             3232920.000     21636900.000
# 1                      29514.917             3232920.000     21636900.000
# 2                      23323.710             3232920.000     21636900.000
# 3                      29514.917             3232920.000     21636900.000
# 4                      23323.710             3232920.000     21636900.000
#
#    ts_diff1_max_location  ts_diff1_max_device_model  ts_diff1_max_os_version  \
# 0           21636900.000               21636900.000             21636900.000
# 1           21636900.000               21636900.000             21636900.000
# 2           21636900.000               21636900.000             21636900.000
# 3           21636900.000               21636900.000             21636900.000
# 4           21636900.000               21636900.000             21636900.000
#
#    ts_diff1_max_browser_version  ts_diff1_min_user_name  ts_diff1_min_ip  \
# 0                  14983200.000                 120.000          120.000
# 1                  21636900.000                 120.000          120.000
# 2                  14983200.000                 120.000          120.000
# 3                  21636900.000                 120.000          120.000
# 4                  14983200.000                 120.000          120.000
#
#    ts_diff1_min_location  ts_diff1_min_device_model  ts_diff1_min_os_version  \
# 0                120.000                    120.000                  120.000
# 1                120.000                    120.000                  120.000
# 2                120.000                    120.000                  120.000
# 3                120.000                    120.000                  120.000
# 4                120.000                    120.000                  120.000
#
#    ts_diff1_min_browser_version  ts_diff1_std_user_name  ts_diff1_std_ip  \
# 0                       120.000              104000.289       379514.305
# 1                       120.000              104000.289       379514.305
# 2                       120.000              104000.289       379514.305
# 3                       120.000              104000.289       379514.305
# 4                       120.000              104000.289       379514.305
#
#    ts_diff1_std_location  ts_diff1_std_device_model  ts_diff1_std_os_version  \
# 0             379514.305                 366936.304               366936.304
# 1             379514.305                 366936.304               366936.304
# 2             379514.305                 366936.304               366936.304
# 3             379514.305                 366936.304               366936.304
# 4             379514.305                 366936.304               366936.304
#
#    ts_diff1_std_browser_version  ts_diff1_sum_user_name  ts_diff1_sum_ip  \
# 0                    314087.243            94140060.000    474243120.000
# 1                    412996.740            94140060.000    474243120.000
# 2                    314087.243            94140060.000    474243120.000
# 3                    412996.740            94140060.000    474243120.000
# 4                    314087.243            94140060.000    474243120.000
#
#    ts_diff1_sum_location  ts_diff1_sum_device_model  ts_diff1_sum_os_version  \
# 0          474243120.000              522283200.000            522283200.000
# 1          474243120.000              522283200.000            522283200.000
# 2          474243120.000              522283200.000            522283200.000
# 3          474243120.000              522283200.000            522283200.000
# 4          474243120.000              522283200.000            522283200.000
#
#    ts_diff1_sum_browser_version  ts_diff1_median_user_name  \
# 0                 230321640.000                    840.000
# 1                 291961560.000                    840.000
# 2                 230321640.000                    840.000
# 3                 291961560.000                    840.000
# 4                 230321640.000                    840.000
#
#    ts_diff1_median_ip  ts_diff1_median_location  ts_diff1_median_device_model  \
# 0             840.000                   840.000                       840.000
# 1             840.000                   840.000                       840.000
# 2             840.000                   840.000                       840.000
# 3             840.000                   840.000                       840.000
# 4             840.000                   840.000                       840.000
#
#    ts_diff1_median_os_version  ts_diff1_median_browser_version  \
# 0                     840.000                          840.000
# 1                     840.000                          840.000
# 2                     840.000                          840.000
# 3                     840.000                          840.000
# 4                     840.000                          840.000
#
#    ts_diff1_prod_user_name  ts_diff1_prod_ip  ts_diff1_prod_location  \
# 0                      inf               inf                     inf
# 1                      inf               inf                     inf
# 2                      inf               inf                     inf
# 3                      inf               inf                     inf
# 4                      inf               inf                     inf
#
#    ts_diff1_prod_device_model  ts_diff1_prod_os_version  \
# 0                         inf                       inf
# 1                         inf                       inf
# 2                         inf                       inf
# 3                         inf                       inf
# 4                         inf                       inf
#
#    ts_diff1_prod_browser_version
# 0                            inf
# 1                            inf
# 2                            inf
# 3                            inf
# 4                            inf

# %%
train = data[data['risk_label'].notna()]
test = data[data['risk_label'].isna()]

print(train.shape, test.shape)
# Out:
# (15016, 70) (10000, 70)

# %%
ycol = 'risk_label'
feature_names = list(
    filter(lambda x: x not in [ycol, 'session_id', 'op_date', 'last_ts'], train.columns))
feature_names
# Out:
# ['user_name',
#  'action',
#  'auth_type',
#  'ip',
#  'ip_location_type_keyword',
#  'ip_risk_level',
#  'location',
#  'device_model',
#  'os_type',
#  'os_version',
#  'browser_type',
#  'browser_version',
#  'bus_system_code',
#  'op_target',
#  'location_first_lvl',
#  'location_sec_lvl',
#  'location_third_lvl',
#  'op_ts',
#  'ts_diff1',
#  'user_ip_nunique',
#  'user_location_nunique',
#  'user_device_model_nunique',
#  'user_os_version_nunique',
#  'user_browser_version_nunique',
#  'ts_diff1_mean_user_name',
#  'ts_diff1_mean_ip',
#  'ts_diff1_mean_location',
#  'ts_diff1_mean_device_model',
#  'ts_diff1_mean_os_version',
#  'ts_diff1_mean_browser_version',
#  'ts_diff1_max_user_name',
#  'ts_diff1_max_ip',
#  'ts_diff1_max_location',
#  'ts_diff1_max_device_model',
#  'ts_diff1_max_os_version',
#  'ts_diff1_max_browser_version',
#  'ts_diff1_min_user_name',
#  'ts_diff1_min_ip',
#  'ts_diff1_min_location',
#  'ts_diff1_min_device_model',
#  'ts_diff1_min_os_version',
#  'ts_diff1_min_browser_version',
#  'ts_diff1_std_user_name',
#  'ts_diff1_std_ip',
#  'ts_diff1_std_location',
#  'ts_diff1_std_device_model',
#  'ts_diff1_std_os_version',
#  'ts_diff1_std_browser_version',
#  'ts_diff1_sum_user_name',
#  'ts_diff1_sum_ip',
#  'ts_diff1_sum_location',
#  'ts_diff1_sum_device_model',
#  'ts_diff1_sum_os_version',
#  'ts_diff1_sum_browser_version',
#  'ts_diff1_median_user_name',
#  'ts_diff1_median_ip',
#  'ts_diff1_median_location',
#  'ts_diff1_median_device_model',
#  'ts_diff1_median_os_version',
#  'ts_diff1_median_browser_version',
#  'ts_diff1_prod_user_name',
#  'ts_diff1_prod_ip',
#  'ts_diff1_prod_location',
#  'ts_diff1_prod_device_model',
#  'ts_diff1_prod_os_version',
#  'ts_diff1_prod_browser_version']

# %%
model = lgb.LGBMClassifier(objective='binary',
                           boosting_type='gbdt',
                           tree_learner='serial',
                           num_leaves=2 ** 8,
                           max_depth=16,
                           learning_rate=0.2,
                           n_estimators=10000,
                           subsample=0.75,
                           feature_fraction=0.55,
                           reg_alpha=0.2,
                           reg_lambda=0.2,
                           random_state=1983,
                           is_unbalance=True,
                           # scale_pos_weight=130,
                           metric='auc')

# %%
from sklearn.model_selection import GridSearchCV

# %%
oof = []
prediction = test[['session_id']]
prediction[ycol] = 0
df_importance_list = []

kfold = StratifiedKFold(n_splits=20, shuffle=True, random_state=1983)
for fold_id, (trn_idx, val_idx) in enumerate(kfold.split(train[feature_names], train[ycol])):
    X_train = train.iloc[trn_idx][feature_names]
    Y_train = train.iloc[trn_idx][ycol]

    X_val = train.iloc[val_idx][feature_names]
    Y_val = train.iloc[val_idx][ycol]

    print('\nFold_{} Training ================================\n'.format(fold_id + 1))

    lgb_model = model.fit(X_train,
                          Y_train,
                          eval_names=['train', 'valid'],
                          eval_set=[(X_train, Y_train), (X_val, Y_val)],
                          verbose=500,
                          eval_metric='auc',
                          early_stopping_rounds=50)
#     params_test1={
#         'max_depth': range(8,16,2),
#         'num_leaves':range(2 ** 6, 2 ** 8, 30)
#     }
    # gsearch1 = GridSearchCV(estimator=model, param_grid=params_test1, scoring='neg_mean_squared_error', cv=5, verbose=1, n_jobs=4)
    # gsearch1.fit(X_train, Y_train)
    # lgb_model = gsearch1.best_estimator_
    # print(gsearch1.cv_results_)
    # print(gsearch1.best_params_)
    pred_val = lgb_model.predict_proba(
        X_val, num_iteration=lgb_model.best_iteration_)
    df_oof = train.iloc[val_idx][['session_id', ycol]].copy()
    df_oof['pred'] = pred_val[:, 1]
    oof.append(df_oof)

    pred_test = lgb_model.predict_proba(
        test[feature_names], num_iteration=lgb_model.best_iteration_)
    prediction[ycol] += pred_test[:, 1] / kfold.n_splits

    df_importance = pd.DataFrame({
        'column': feature_names,
        'importance': lgb_model.feature_importances_,
    })
    df_importance_list.append(df_importance)

    del lgb_model, pred_val, pred_test, X_train, Y_train, X_val, Y_val
    gc.collect()

df_importance = pd.concat(df_importance_list)
df_importance = df_importance.groupby(['column'])['importance'].agg(
    'mean').sort_values(ascending=False).reset_index()
df_importance
# Out:
# Fold_1 Training ================================
#
# [LightGBM] [Warning] feature_fraction is set=0.55, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.55
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [5]	train's auc: 0.77898	valid's auc: 0.527369
#
# Fold_2 Training ================================
#
# [LightGBM] [Warning] feature_fraction is set=0.55, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.55
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [8]	train's auc: 0.810892	valid's auc: 0.523122
#
# Fold_3 Training ================================
#
# [LightGBM] [Warning] feature_fraction is set=0.55, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.55
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [9]	train's auc: 0.837103	valid's auc: 0.533681
#
# Fold_4 Training ================================
#
# [LightGBM] [Warning] feature_fraction is set=0.55, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.55
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [79]	train's auc: 0.955192	valid's auc: 0.490235
#
# Fold_5 Training ================================
#
# [LightGBM] [Warning] feature_fraction is set=0.55, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.55
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [15]	train's auc: 0.875188	valid's auc: 0.50834
#
# Fold_6 Training ================================
#
# [LightGBM] [Warning] feature_fraction is set=0.55, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.55
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [53]	train's auc: 0.943001	valid's auc: 0.517531
#
# Fold_7 Training ================================
#
# [LightGBM] [Warning] feature_fraction is set=0.55, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.55
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [6]	train's auc: 0.794904	valid's auc: 0.503261
#
# Fold_8 Training ================================
#
# [LightGBM] [Warning] feature_fraction is set=0.55, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.55
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [13]	train's auc: 0.868641	valid's auc: 0.507546
#
# Fold_9 Training ================================
#
# [LightGBM] [Warning] feature_fraction is set=0.55, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.55
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [4]	train's auc: 0.773067	valid's auc: 0.504477
#
# Fold_10 Training ================================
#
# [LightGBM] [Warning] feature_fraction is set=0.55, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.55
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [12]	train's auc: 0.871321	valid's auc: 0.52622
#
# Fold_11 Training ================================
#
# [LightGBM] [Warning] feature_fraction is set=0.55, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.55
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [10]	train's auc: 0.837678	valid's auc: 0.533265
#
# Fold_12 Training ================================
#
# [LightGBM] [Warning] feature_fraction is set=0.55, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.55
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [99]	train's auc: 0.969975	valid's auc: 0.53309
#
# Fold_13 Training ================================
#
# [LightGBM] [Warning] feature_fraction is set=0.55, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.55
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [28]	train's auc: 0.903908	valid's auc: 0.534875
#
# Fold_14 Training ================================
#
# [LightGBM] [Warning] feature_fraction is set=0.55, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.55
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [25]	train's auc: 0.898553	valid's auc: 0.559349
#
# Fold_15 Training ================================
#
# [LightGBM] [Warning] feature_fraction is set=0.55, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.55
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	train's auc: 0.648324	valid's auc: 0.538575
#
# Fold_16 Training ================================
#
# [LightGBM] [Warning] feature_fraction is set=0.55, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.55
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [7]	train's auc: 0.816684	valid's auc: 0.574042
#
# Fold_17 Training ================================
#
# [LightGBM] [Warning] feature_fraction is set=0.55, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.55
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [122]	train's auc: 0.98324	valid's auc: 0.545492
#
# Fold_18 Training ================================
#
# [LightGBM] [Warning] feature_fraction is set=0.55, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.55
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [59]	train's auc: 0.940269	valid's auc: 0.546869
#
# Fold_19 Training ================================
#
# [LightGBM] [Warning] feature_fraction is set=0.55, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.55
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [9]	train's auc: 0.835956	valid's auc: 0.505663
#
# Fold_20 Training ================================
#
# [LightGBM] [Warning] feature_fraction is set=0.55, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.55
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	train's auc: 0.645808	valid's auc: 0.514322
#                              column  importance
# 0                             op_ts    1449.050
# 1                          ts_diff1    1098.250
# 2                   bus_system_code     507.100
# 3                         auth_type     308.150
# 4                         user_name     185.400
# 5           ts_diff1_mean_user_name     175.600
# 6            ts_diff1_sum_user_name     165.600
# 7                         op_target     150.550
# 8                   browser_version     136.750
# 9                      browser_type     117.350
# 10           ts_diff1_max_user_name     113.150
# 11    ts_diff1_mean_browser_version     107.750
# 12     ts_diff1_max_browser_version      80.750
# 13                               ip      62.350
# 14     ts_diff1_sum_browser_version      52.600
# 15           ts_diff1_std_user_name      51.250
# 16                           action      44.350
# 17                         location      37.200
# 18     ts_diff1_std_browser_version      31.750
# 19               location_third_lvl      30.050
# 20                 ts_diff1_mean_ip      27.450
# 21                     device_model      24.000
# 22                  user_ip_nunique      17.850
# 23                  ts_diff1_max_ip      15.450
# 24         ip_location_type_keyword      12.000
# 25                       os_version      10.900
# 26            ts_diff1_max_location      10.800
# 27           ts_diff1_mean_location      10.550
# 28                    ip_risk_level       9.400
# 29                  ts_diff1_sum_ip       8.900
# 30       ts_diff1_mean_device_model       6.400
# 31                 location_sec_lvl       6.250
# 32        ts_diff1_median_user_name       6.000
# 33        ts_diff1_sum_device_model       5.400
# 34         ts_diff1_mean_os_version       4.500
# 35            user_location_nunique       4.300
# 36               ts_diff1_median_ip       2.900
# 37          ts_diff1_sum_os_version       2.850
# 38            ts_diff1_sum_location       2.350
# 39        user_device_model_nunique       2.300
# 40                          os_type       2.150
# 41                  ts_diff1_std_ip       1.750
# 42        ts_diff1_max_device_model       1.700
# 43         ts_diff1_median_location       1.550
# 44          user_os_version_nunique       1.550
# 45          ts_diff1_max_os_version       1.450
# 46               location_first_lvl       0.950
# 47  ts_diff1_median_browser_version       0.650
# 48            ts_diff1_std_location       0.550
# 49        ts_diff1_std_device_model       0.400
# 50     ts_diff1_median_device_model       0.250
# 51       ts_diff1_median_os_version       0.200
# 52     user_browser_version_nunique       0.150
# 53                  ts_diff1_min_ip       0.000
# 54     ts_diff1_min_browser_version       0.000
# 55        ts_diff1_min_device_model       0.000
# 56                 ts_diff1_prod_ip       0.000
# 57           ts_diff1_prod_location       0.000
# 58          ts_diff1_min_os_version       0.000
# 59           ts_diff1_min_user_name       0.000
# 60          ts_diff1_std_os_version       0.000
# 61    ts_diff1_prod_browser_version       0.000
# 62       ts_diff1_prod_device_model       0.000
# 63          ts_diff1_prod_user_name       0.000
# 64         ts_diff1_prod_os_version       0.000
# 65            ts_diff1_min_location       0.000

# %%
df_oof = pd.concat(oof)
print('roc_auc_score', roc_auc_score(df_oof[ycol], df_oof['pred']))
# Out:
# roc_auc_score 0.5244012833685976

# %%
prediction['id'] = range(len(prediction))
prediction['id'] = prediction['id'] + 1
prediction = prediction[['id', 'risk_label']].copy()
prediction.columns = ['id', 'ret']
prediction.head()
# Out:
#       id   ret
# 6147   1 0.302
# 6148   2 0.428
# 6149   3 0.420
# 6150   4 0.437
# 6151   5 0.409

# %%
from time import time
timestamp = str(time())
prediction.to_csv(os.path.join('./result/',timestamp + '.csv'), index=False)
